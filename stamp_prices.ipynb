# %% [markdown]
# <a href="https://colab.research.google.com/github/amscally-dsci/stamp-prices/blob/main/stamp_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Plot US Stamp Prices Over Time

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# This data set is from https://vincentarelbundock.github.io/Rdatasets/datasets.html

# %%
# pd.read_csv will turn a csv file--without downloading it--into a pandas data frame. Do not download the csv to your computer
stamp_prices=pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/USstamps.csv')

# %%
# type() returns the type of object
type(stamp_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
# head() returns the column names and the first few rows from the data frame
stamp_prices.head()
# Out:
#    rownames  Year  Price
# 0         1  1885      2
# 1         2  1917      3
# 2         3  1919      2
# 3         4  1932      3
# 4         5  1958      4

# %%
# Plot the year vs. the price
# First set a plot title
plt.title('US Stamp Prices Over Time')

# Set the columns to plot
plt.scatter(stamp_prices['Year'],stamp_prices['Price'])
